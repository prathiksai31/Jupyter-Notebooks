# %% [markdown]
# # TE-ETRX Results Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_data = pd.read_csv('Data.csv',header=None, usecols=[2,3,8,12,16,20,24,28,31,34,37,40,43], sep=',')
my_data.head(5)
# Out:
#             2       3   8   12  16  20  24  28  31  34  37  40  43
# 0         Atre  Prutha  84  93  80  69  85  68  53  27  28  54  98
# 1  Barwaniwala   Abbas  86  96  97  83  89  76  57  28  29  58  91
# 2       Bhagat   Sahil  48  81  59  42  52  50  51  28  29  57  98
# 3    Deshpande   Varun  69  85  45  48  74  67  41  28  27  53  40
# 4       Dongre    Isha  66  84  72  56  68  60  44  27  27  52  92

# %%
my_data.columns = ['Last name','First name','BVLSI', 'AIS','CO','PE','DSPP','MITM','BVLSI_LAB','AIS_LAB','PE_LAB','DSPP_LAB','MP1']
#my_data

# %%
my_data_index = my_data

# %%
my_data_index.index = my_data["First name"]

# %%
my_data["AIS"].mean()
# Out:
# 78.84210526315789

# %%
first_five = my_data_index.head(5)
first_five.plot(kind = 'bar', width=0.8)

# %%
#Top 10 scorers in BVLSI
top_bvlsi = my_data.nlargest(10, 'BVLSI')
#print(top_bvlsi.iloc[:,[0,2]])

top_bvlsi_plot = top_bvlsi.iloc[:,[0,2]]
top_bvlsi_plot.plot(kind = 'bar', width=0.8)
#top_bvlsi_plot.plot()
top_bvlsi.iloc[:,[0,2]]
# Out:
#               Last name  BVLSI
# First name
# Bhushan        Sonawane     97
# Anchal          Jaiswal     94
# Saurabh          Thakur     94
# Adithya       Ramanujam     90
# Anushka      Waingankar     90
# Amey            Mahadik     88
# Rajas        Khasgiwale     87
# Jay                Rana     87
# Abbas       Barwaniwala     86
# Rohan            Mestri     86

# %%
#Top 10 scorers in AIS
top_ais = my_data.nlargest(10, 'AIS')
#print(top_ais.iloc[:,[0,3]])
top_ais_plot = top_ais.iloc[:,[0,3]]
top_ais_plot.plot(kind = 'bar', width=0.8)
top_ais.iloc[:,[0,3]]
# Out:
#               Last name  AIS
# First name
# Abbas       Barwaniwala   96
# Darshana          Mehta   95
# Bhushan        Sonawane   95
# Naman             Patwa   95
# Prutha             Atre   93
# Chirag             Shah   93
# Isha              Yadav   93
# Shivam             Sahu   92
# Vrinda          Singhal   92
# Nevil         Pooniwala   92

# %%
#Top 10 scorers in CO
top_pe = my_data.nlargest(10, 'CO')
#print(top_pe.iloc[:,[0,4]])
top_co_plot = top_pe.iloc[:,[0,4]]
top_co_plot.plot(kind = 'bar', width=0.8)
top_pe.iloc[:,[0,4]]
# Out:
#               Last name  CO
# First name
# Abbas       Barwaniwala  97
# Adithya       Ramanujam  94
# Bhushan        Sonawane  91
# Saurabh          Thakur  90
# Anchal          Jaiswal  89
# Srijal          Poojari  89
# Jay                Rana  88
# Vrinda          Singhal  88
# Nikhil            Pinto  87
# Tejas             Dhebe  87

# %%
#Top 10 scorers in PE
top_pe = my_data.nlargest(10, 'PE')
top_pe_plot = top_pe.iloc[:,[0,5]]
top_pe_plot.plot(kind = 'bar', width=0.8)
top_pe.iloc[:,[0,5]]
# Out:
#               Last name  PE
# First name
# Abbas       Barwaniwala  83
# Bhushan        Sonawane  74
# Saurabh          Thakur  74
# Naman             Patwa  74
# Tejas             Dhebe  73
# Rutuparna        Patkar  73
# Chirag             Shah  72
# Adithya       Ramanujam  71
# Nisha            Shetty  70
# Isha              Yadav  70

# %%
#Top 10 scorers in DSPP
top_dspp = my_data.nlargest(10, 'DSPP')
top_dspp_plot = top_dspp.iloc[:,[0,6]]
top_dspp_plot.plot(kind = 'bar', width=0.8)
top_dspp.iloc[:,[0,6]]
# Out:
#               Last name  DSPP
# First name
# Adithya       Ramanujam    96
# Anchal          Jaiswal    93
# Rajas        Khasgiwale    91
# Amey            Mahadik    91
# Bhushan        Sonawane    90
# Harshali         Sawant    90
# Abbas       Barwaniwala    89
# Saurabh          Thakur    89
# Rutuparna        Patkar    89
# Aditya          Khopkar    88

# %%
#Top 10 scorers in MITM
top_mitm = my_data.nlargest(10, 'MITM')
top_mitm_plot = top_mitm.iloc[:,[0,7]]
top_mitm_plot.plot(kind = 'bar', width=0.8)
top_mitm.iloc[:,[0,7]]
# Out:
#               Last name  MITM
# First name
# Naman             Patwa    84
# Bhushan        Sonawane    80
# Abbas       Barwaniwala    76
# Saiprathik    Ravipalli    76
# Chirag             Shah    73
# Vrinda          Singhal    72
# Isha              Yadav    71
# Darshana          Mehta    70
# Tejas             Dhebe    70
# Adithya       Ramanujam    69
